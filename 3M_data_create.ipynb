# %%
import numpy as np
import pandas as pd

# %%
dfs = []
df=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\BPCL.csv")
df_1=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\BSE.csv")
df_2=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\ETHOS_LTD.csv")
df_3=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\FORTIS.csv")
df_4=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\GLENMARK.csv")
df_5=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\HDFCLIFE.csv")
df_6=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\HINDPETRO.csv")
df_7=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\HINDUUNILVR.csv")
df_8=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\IOC.csv")
df_9=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\JSL.csv")
df_10=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\LT.csv")
df_11=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\M&M.csv")
df_12=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\POWERINDIA.csv")
df_13=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\TATAMOTORS.csv")
df_14=pd.read_csv(r"C:\Users\Dell\Desktop\Research Project\Datasets\TITAN.csv")

# %%
df.columns = df.columns.str.strip().str.replace(' ', '')
df_1.columns = df_1.columns.str.strip().str.replace(' ', '')
df_2.columns = df_2.columns.str.strip().str.replace(' ', '')
df_3.columns = df_3.columns.str.strip().str.replace(' ', '')
df_4.columns = df_4.columns.str.strip().str.replace(' ', '')
df_5.columns = df_5.columns.str.strip().str.replace(' ', '')
df_6.columns = df_6.columns.str.strip().str.replace(' ', '')
df_7.columns = df_7.columns.str.strip().str.replace(' ', '')
df_8.columns = df_8.columns.str.strip().str.replace(' ', '')
df_9.columns = df_9.columns.str.strip().str.replace(' ', '')
df_10.columns = df_10.columns.str.strip().str.replace(' ', '')
df_11.columns = df_11.columns.str.strip().str.replace(' ', '')
df_12.columns = df_12.columns.str.strip().str.replace(' ', '')
df_13.columns = df_13.columns.str.strip().str.replace(' ', '')
df_14.columns = df_14.columns.str.strip().str.replace(' ', '')

# %%
for df in [df,df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12,df_13,df_14]:
    df = df.drop(['series','OPEN','HIGH','LOW','PREV.CLOSE','close','vwap','52WH','52WL','VOLUME','VALUE','Nooftrades'],axis=1)
    df_pivot = df.pivot(index='Company', columns='Date', values='ltp')
    dfs.append(df_pivot)

# %%
df1 = df1.pivot(index='Company', columns='Date', values='ltp')

df1 = pd.concat(dfs)

# %%
df1
# Out:
# Date       01-Jun-23 02-Jun-23 02-May-23 03-Jul-23 03-May-23 04-Jul-23  \
# Company
# BPCL           364.5     359.8     360.6    375.05     360.6     376.8
# BSE              571       572       529       668     519.6       673
# ETHOS_LTD   1,259.95  1,279.00  1,301.00  1,442.90  1,308.00  1,484.00
# FORTIS        278.05     276.6       261       313     263.7    313.45
# GLENMARK       609.6       614       543       659       543     650.2
# HDFCLIFE         581     576.1    544.25     650.7    538.45       648
# HINDPETRO     260.25    258.65       252    284.35     256.9     279.4
# HINDUNILVR  2,691.00  2,711.05  2,450.90  2,700.20  2,485.20  2,701.55
# IOC             90.6      89.9     82.05      95.7      82.8     94.55
# JSL            292.7    290.05       286     340.5     288.9    342.95
# LT          2,209.40  2,236.00  2,387.00  2,456.00  2,355.80  2,463.00
# M&M         1,319.80  1,343.00  1,234.00  1,471.70  1,235.00  1,467.55
# ...

# %%
df1.iloc[1]
# Out:
# Date
# 01-Jun-23       571
# 02-Jun-23       572
# 02-May-23       529
# 03-Jul-23       668
# 03-May-23     519.6
#               ...
# 28-Jun-23       617
# 29-May-23    540.55
# 30-Jun-23    608.95
# 30-May-23    542.95
# 31-May-23     557.2
# Name: BSE, Length: 62, dtype: object

# %%
#df2 = df1
#df2.columns = pd.to_datetime(df2.columns, format='%d-%b-%y')
#df2 = df2.reindex(sorted(df2.columns), axis=1)
df2
# Out:
# Date       2023-04-10 2023-04-11 2023-04-12 2023-04-13 2023-04-17 2023-04-18  \
# Company
# BPCL            335.4      338.5      337.5     332.35      335.5      334.4
# BSE               458      463.6      462.6      459.8        461      467.1
# ETHOS_LTD    1,002.00   1,010.00   1,000.60   1,042.60   1,194.00   1,197.00
# FORTIS          255.7      257.2        265     265.35        265     264.95
# GLENMARK        487.3      484.5      491.9      490.1     490.75      505.5
# HDFCLIFE          514      512.9     517.95     531.35      532.9        533
# HINDPETRO         229      231.4      229.9      225.1        227      228.2
# HINDUNILVR   2,527.80   2,546.00   2,528.10   2,535.40   2,555.50   2,538.25
# IOC             77.85      77.95      78.15      77.25      77.35      77.95
# JSL             283.3     276.95      264.8     265.05        263      261.5
# LT           2,310.00   2,302.70   2,289.00   2,263.50   2,213.00   2,222.00
# ...

# %%
df2.to_csv('3M_data.csv')
